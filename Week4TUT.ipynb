# %% [markdown]
# <a href="https://colab.research.google.com/github/HamzahSarmad/Y3_CO3093_Big_Data_And_Predictive_Analytics/blob/main/Week4TUT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Read dataset and store into dataframe

# %%
file1 = "/content/sample_data/Automobile_price_data_Raw.csv"
data = pd.read_csv(file1)

# %%
pd.isnull(data).sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ## Replace missing values with nan

# %%
data = data.replace('?', np.nan)
data = data.replace('^\s+', np.nan, regex=True)
pd.isnull(data).sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
data.shape
# Out:
# (205, 26)

# %% [markdown]
# ## Ensure all values in cols are numeric

# %%
cols = ['price','bore','stroke', 'horsepower','peak-rpm']
for col in cols:
  data[col] = pd.to_numeric(data[col], errors='coerce')

data.dropna(axis=0, inplace=True)
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# ## Show shape

# %%
data.shape
# Out:
# (159, 26)

# %% [markdown]
# ## Show summary

# %%
data.describe()
# Out:
#         symboling  wheel-base  ...  highway-mpg         price
# count  159.000000  159.000000  ...   159.000000    159.000000
# mean     0.735849   98.264151  ...    32.081761  11445.729560
# std      1.193086    5.167416  ...     6.459189   5877.856195
# min     -2.000000   86.600000  ...    18.000000   5118.000000
# 25%      0.000000   94.500000  ...    28.000000   7372.000000
# 50%      1.000000   96.900000  ...    32.000000   9233.000000
# 75%      2.000000  100.800000  ...    37.000000  14719.500000
# max      3.000000  115.600000  ...    54.000000  35056.000000
#
# [8 rows x 15 columns]

# %% [markdown]
# ## Group numerical data and calculate averages

# %%
print(data['fuel-type'].unique())
data.groupby('fuel-type').mean()
# Out:
# ['gas' 'diesel']
#            symboling  wheel-base  ...  highway-mpg         price
# fuel-type                         ...
# diesel      0.133333  103.686667  ...    35.066667  16189.600000
# gas         0.798611   97.699306  ...    31.770833  10951.576389
#
# [2 rows x 15 columns]

# %% [markdown]
# ## Compute log of prices and add to df

# %%
data['lnprice'] = np.log(data.price)
data.head(5)
# Out:
#     symboling normalized-losses  make  ... highway-mpg    price    lnprice
# 3           2               164  audi  ...          30  13950.0   9.543235
# 4           2               164  audi  ...          22  17450.0   9.767095
# 6           1               158  audi  ...          25  17710.0   9.781885
# 8           1               158  audi  ...          20  23875.0  10.080587
# 10          2               192   bmw  ...          29  16430.0   9.706864
#
# [5 rows x 27 columns]

# %% [markdown]
# # Exercise 2

# %%
def describe(df, col):
  desc = df[col].describe()
  idx = desc.index.tolist()
  idx[5] = 'median'
  desc.index = idx
  return data

describe(data, 'price')
# Out:
#      symboling normalized-losses   make  ... highway-mpg    price    lnprice
# 3            2               164   audi  ...          30  13950.0   9.543235
# 4            2               164   audi  ...          22  17450.0   9.767095
# 6            1               158   audi  ...          25  17710.0   9.781885
# 8            1               158   audi  ...          20  23875.0  10.080587
# 10           2               192    bmw  ...          29  16430.0   9.706864
# ..         ...               ...    ...  ...         ...      ...        ...
# 200         -1                95  volvo  ...          28  16845.0   9.731809
# 201         -1                95  volvo  ...          25  19045.0   9.854560
# 202         -1                95  volvo  ...          23  21485.0   9.975110
# 203         -1                95  volvo  ...          27  22470.0  10.019936
# 204         -1                95  volvo  ...          25  22625.0  10.026811
#
# [159 rows x 27 columns]

# %%
def plotstats(df, col):
  fig = plt.figure(1)
  fig.set_size_inches(12,8)
  
  plt.subplot(2,1,1)
  df.dropna().boxplot(col, vert=False)
  plt.subplot(2,1,2)
  temp = df[col]
  plt.hist(temp, bins=30)
  plt.ylabel('Number of Cars')
  plt.xlabel(col)
  plt.show()

plotstats(data, 'price')
